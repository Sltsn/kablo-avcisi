# %%
# 1. ADIM: Kurulum
# !pip install ultralytics roboflow -q
import ultralytics
from roboflow import Roboflow
ultralytics.checks()

# 2. ADIM: Veriyi Çek (Hatalı ismi düzelttik)
rf = Roboflow(api_key="uddimJI8UwaTxWQiTEwZ")
# Buradaki "Power Line" kısmını URL'deki gerçek isimle değiştirdik:
project = rf.workspace("sla-7p32f").project("power-line-idqfy-9mm3e")
dataset = project.version(1).download("yolov8")

# 3. ADIM: Eğitimi Başlat
# Kaybolmasın diye save_period=5 ekledim
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=30 imgsz=640 batch=16 patience=10 device=0 save_period=5
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6842.1/8062.4 GB disk)
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Power-Line-1 in yolov8:: 100%|██████████| 3634/3634 [00:03<00:00, 970.57it/s]
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
